# %% [markdown]
# # Qwen 2.5 3B DPO Training on RunPod
#
# This notebook walks through fine-tuning **Qwen 2.5 3B Instruct** using Direct Preference Optimization (DPO) inside a RunPod instance that exposes only a Jupyter Notebook interface. Follow each section in order. The only manual input you need is uploading your JSONL dataset when prompted.

# %% [markdown]
# ## 1. Install Dependencies
# These steps prepare the RunPod environment with system packages and Python libraries required for DPO training.
